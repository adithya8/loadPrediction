# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
import matplotlib as plt

path = "J:\\SF\\Thermal Load Prediction\\Datas\\Low Carbon London 168 homes\\"
read = pd.read_csv(path+"Power-Networks-LCL-June2015(withAcornGps)v2_1.csv")
read = read[read.columns[3:4]]

ndf = pd.concat([read.shift(4), read.shift(2), read], axis=1)
ndf.columns = ('t-2', 't-1', 't')
ndf = ndf.iloc[4:]
sh = int(ndf.shape[0]*.20)

x = ndf[ndf.columns[0:2]]
y = ndf[ndf.columns[-1:]]

for i in range(x.shape[0]):
    if(x.values[i][0]=='Null'):
        x.values[i][0]='0'
    elif(x.values[i][1]=='Null'):
        x.values[i][1]='0'
    elif(y.values[i][0]=='Null'):
        y.values[i][0]='0'

x = np.array(x, dtype=float)
y = np.array(y, dtype=float)

act = ['linear','sigmoid','tanh','softsign']
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=1)
for i in range(4):
    print(act[i])
    model = Sequential()
    model.add(Dense(5,input_dim=2,kernel_initializer='normal', activation=act[i]))
    #Output Layer.
    model.add(Dense(1,kernel_initializer='normal'))
    #Compile model.
    model.compile(loss='mean_squared_error',optimizer='adam',metrics=['mean_squared_error'])
    #Fit the model.
    his = model.fit(X_train,y_train,epochs=3,batch_size=200,verbose=2)
    print(his)
    #Final Evaluation of the model.
    scores = model.evaluate(X_test,y_test,verbose=0)
    print ("Baseline Error : %.5f" % (100-scores[1]*100))
    model.summary()
# Out:
# linear
# Epoch 1/3
#  - 24s - loss: 0.0799 - mean_squared_error: 0.0799
# Epoch 2/3
#  - 23s - loss: 0.0765 - mean_squared_error: 0.0765
# Epoch 3/3
#  - 23s - loss: 0.0765 - mean_squared_error: 0.0765
# <keras.callbacks.History object at 0x0000020596181358>
# Baseline Error : 92.01634
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_43 (Dense)             (None, 5)                 15
# _________________________________________________________________
# dense_44 (Dense)             (None, 1)                 6
# =================================================================
# Total params: 21
# Trainable params: 21
# Non-trainable params: 0
# _________________________________________________________________
# sigmoid
# Epoch 1/3
#  - 23s - loss: 0.0969 - mean_squared_error: 0.0969
# Epoch 2/3
#  - 22s - loss: 0.0783 - mean_squared_error: 0.0783
# Epoch 3/3
#  - 22s - loss: 0.0768 - mean_squared_error: 0.0768
# <keras.callbacks.History object at 0x000002056D993C50>
# Baseline Error : 92.00829
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_45 (Dense)             (None, 5)                 15
# _________________________________________________________________
# dense_46 (Dense)             (None, 1)                 6
# =================================================================
# Total params: 21
# Trainable params: 21
# Non-trainable params: 0
# _________________________________________________________________
# tanh
# Epoch 1/3
#  - 24s - loss: 0.0843 - mean_squared_error: 0.0843
# Epoch 2/3
#  - 25s - loss: 0.0778 - mean_squared_error: 0.0778
# Epoch 3/3
#  - 22s - loss: 0.0774 - mean_squared_error: 0.0774
# <keras.callbacks.History object at 0x00000205707287F0>
# Baseline Error : 91.92752
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_47 (Dense)             (None, 5)                 15
# _________________________________________________________________
# dense_48 (Dense)             (None, 1)                 6
# =================================================================
# Total params: 21
# Trainable params: 21
# Non-trainable params: 0
# _________________________________________________________________
# softsign
# Epoch 1/3
#  - 23s - loss: 0.0888 - mean_squared_error: 0.0888
# Epoch 2/3
#  - 25s - loss: 0.0778 - mean_squared_error: 0.0778
# Epoch 3/3
#  - 24s - loss: 0.0762 - mean_squared_error: 0.0762
# <keras.callbacks.History object at 0x0000020593D15278>
# Baseline Error : 92.08963
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_49 (Dense)             (None, 5)                 15
# _________________________________________________________________
# dense_50 (Dense)             (None, 1)                 6
# =================================================================
# Total params: 21
# Trainable params: 21
# Non-trainable params: 0
# _________________________________________________________________
